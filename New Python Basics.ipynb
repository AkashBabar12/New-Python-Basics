# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# %matplotlib inline

# %%
x = [-3,5,7]

# %%
y = [10,2,5]

# %%
plt.plot(x,y)

# %%
fig = plt.figure(figsize=(15,3))

plt.plot(x,y)
plt.xlim(0,10)
plt.ylim(-3,8)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
fig.get_size_inches()
# Out:
# array([15.,  3.])

# %%
fig.set_size_inches(15,3)

# %%
fig

# %%
import pandas as pd
import numpy as np
mtcars = pd.read_csv("C:\Users\lenovo\Desktop\DATA SCIENCE\mtcars.csv")
# Out:
#   File "<ipython-input-4-c15a7651ef25>", line 3
#     mtcars = pd.read_csv("C:\Users\lenovo\Desktop\DATA SCIENCE\mtcars.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
mtcars = pd.read_csv(r"C:\Users\lenovo\Desktop\mtcars.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f96a5726fd2> in <module>
# ----> 1 mtcars = pd.read_csv(r"C:\Users\lenovo\Desktop\mtcars.csv")
#
# NameError: name 'pd' is not defined

# %%
C:\Users\lenovo\Desktop\DATA SCIENCE

# %%
mtcars = pd.read_csv(r"C:\Users\lenovo\Desktop\DATA SCIENCE\pandas-intro.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f093b75c714b> in <module>
# ----> 1 mtcars = pd.read_csv(r"C:\Users\lenovo\Desktop\DATA SCIENCE\pandas-intro.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
mtcars = pd.read_csv("C:\Users\lenovo\Desktop\DATA SCIENCE\mtcars.csv")
# Out:
#   File "<ipython-input-12-6c2e07386813>", line 1
#     mtcars = pd.read_csv("C:\Users\lenovo\Desktop\DATA SCIENCE\mtcars.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
